# %%
##  Hangman Game 
#Introduction 
#This game is very simple . A list of word is already prepared in the game, randomly a  word will get 
#selected and your task is to predict the letters in the word .You have got 6 lives to predict the complete word.
#for every wrong prediction 1 chance will be lost and you will see your portrait moving close to get hanging.

import random # importing random library to shuffle the list of words
stages = ['''
  +---+
  |   |     
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["elephant", "leopard", "camel"] # you can change the list of words 
#chosen_word = random.choice(word_list)    
print(chosen_word)    #when the "#" is removed you will be able to see the chosen word
word_length = len(chosen_word)

lives = 6 # you have got 6 lives 
display = []  
for _ in range(word_length):
    display += "_"
while not end_of_game:
    guess = input("Guess a letter: Your choice is ... ").lower()
    for position in range(word_length):
        letter = chosen_word[position]    
        if letter == guess:
            display[position] = letter

    if guess not in chosen_word:
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose the game  .")

    print(f"{' '.join(display)}")

    if "_" not in display:
        end_of_game = True
        print("You win the game.")

    print(stages[lives])
    
# if your guesses are correct and you predict the name correctly you will win the game
